# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import make_blobs

# %%
#create some summy datapoint

data=make_blobs(n_samples=200,n_features=2,centers=4,cluster_std=1.8,random_state=42)

# %%
input1=data[0][ :,0]
dt=data[0][:,1]

# %%
dt.shape
# Out:
# (200,)

# %%
plt.scatter(input1,dt,c=data[1])

# %%
# Import K-Means library
# Call the Kmean alogorith/Give the value of KMean.
# Fit on input data

# %%
from sklearn.cluster import KMeans

# %%
k_model= KMeans(n_clusters=3)

# %%
k_model.fit(data[0])
# Out:
# KMeans(n_clusters=3)
